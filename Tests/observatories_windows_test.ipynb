# %%
# Cell 1: Setup and Render Global Map
import os
import sys

# 1. Tell the notebook to look one folder up for your custom modules
sys.path.append(os.path.abspath('..'))

# 2. Import your setup and your pre-configured telescopes
from core.config.settings import setup_libraries, MAST, SOXS, WILDS

# 3. Suppress astropy warnings 
setup_libraries()

# 4. Generate the map using SOXS as the base time reference
print(f"Generating terminator map for {SOXS.name} local time...")
SOXS.render_global_map(other_telescopes=[MAST, WILDS], local_time_str="2026-04-11 22:00")
# Out:
# Libraries configured and ready.
# Generating terminator map for SOXS local time...
